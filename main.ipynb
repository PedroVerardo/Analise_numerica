# %% [markdown]
# # Spline cúbicas
# -

# %% [markdown]
# ## Generate random points

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_points = 5

arr = np.random.rand(num_points, 2)
arr = arr*10
arr
# Out:
# array([[0.73719539, 5.22481374],
#        [3.43489563, 4.57638759],
#        [0.51275045, 9.86392604],
#        [4.2134761 , 0.04745827],
#        [1.79940663, 5.45678372]])

# %%
x = arr[:, 0]
y = arr[:, 1]

plt.scatter(x, y)

# %%
plt.scatter(x, y)
plt.plot(x, y, color='red', linewidth=1)


plt.show()

# %%
#creating a closed cubic spline
arr2 = arr.copy()
arr2[num_points - 1] = arr2[0]
arr2
# Out:
# array([[0.73719539, 5.22481374],
#        [3.43489563, 4.57638759],
#        [0.51275045, 9.86392604],
#        [4.2134761 , 0.04745827],
#        [0.73719539, 5.22481374]])

# %%
xclosed = arr2[:, 0]
yclosed = arr2[:, 1]

plt.scatter(xclosed, yclosed)
plt.plot(xclosed, yclosed, color='red', linewidth=1)


plt.show()

# %% [markdown]
# ## Generate h vslues

# %% [markdown]
# ## Open

# %%
from spline_utils import plot_spline
import numpy as np

#P = np.array([[0, 0], [1, 2], [3, 3], [4, 0], [5, -1]])
V = np.array([1, 3, 0.5, 0.4, 0.2])
plot_spline(arr, V)
# Out:
# open

# %% [markdown]
# ## Closed

# %%
plot_spline(arr2,V)
# Out:
# closed
