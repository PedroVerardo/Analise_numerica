# %% [markdown]
# # Spline cúbicas
# -

# %% [markdown]
# ## Generate random points

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_points = 5

arr = np.random.rand(num_points, 2)
arr = arr*50
arr
# Out:
# array([[17.07608269, 36.91775671],
#        [29.68554946, 13.87033589],
#        [41.31511478, 21.26489428],
#        [24.85393565, 21.19206707],
#        [25.51132098, 20.85461493]])

# %%
x = arr[:, 0]
y = arr[:, 1]

plt.scatter(x, y)

# %%
plt.scatter(x, y)
plt.plot(x, y, color='red', linewidth=1)


plt.show()

# %%
#creating a closed cubic spline
arr2 = arr.copy()
arr2[num_points - 1] = arr2[0]
arr2
# Out:
# array([[17.07608269, 36.91775671],
#        [29.68554946, 13.87033589],
#        [41.31511478, 21.26489428],
#        [24.85393565, 21.19206707],
#        [17.07608269, 36.91775671]])

# %%
xclosed = arr2[:, 0]
yclosed = arr2[:, 1]

plt.scatter(xclosed, yclosed)
plt.plot(xclosed, yclosed, color='red', linewidth=1)


plt.show()

# %% [markdown]
# ## Generate h vslues

# %% [markdown]
# ## Open

# %%
from spline_utils import plot_spline
import numpy as np

#P = np.array([[0, 0], [1, 2], [3, 3], [4, 0], [5, -1]])
V = np.array([1, 1, 1, 1, 1])
plot_spline(arr, V)
# Out:
# open
# h:  [ 0.         26.27132007 13.78137451 16.46134023  0.73893804  0.        ]
# gamma:  [1.         0.18116821 0.21049735 0.73877269 1.        ]
# mu:  [0.         0.21628348 0.14571605 0.94271854 0.        ]
# lambda:  [1.         0.91321117 0.84253962 0.97257876 1.        ]
# a:  [0.         0.0298624  0.08570688 0.00117804 0.        ]
# b:  [1.         0.82827318 0.84789142 0.09660338 1.        ]
# c:  [0.         0.14186443 0.06640169 0.90221858 0.        ]
# delta:  [0.         0.65591892 0.45569238 0.95703918 1.        ]
# L:  [array([26.69079657, 13.84070082]), array([41.83097333, 20.36711368]), array([19.18825263, 24.26977108]), array([25.51132098, 20.85461493])]
# R:  [array([17.07608269, 36.91775671]), array([31.25653299, 13.88588182]), array([40.69894089, 22.33725989]), array([25.10826419, 21.05391109])]

# %% [markdown]
# ## Closed

# %%
plot_spline(arr2,V)
# Out:
# closed
# h:  [17.54401069 26.27132007 13.78137451 16.46134023 17.54401069 17.54401069]
# gamma:  [0.15975401 0.18116821 0.21049735 0.19060834 0.18566645]
# mu:  [0.08877591 0.21628348 0.12775928 0.13106926 0.13606802]
# lambda conta 0 :  20.80134488949774
# lambda conta 1 :  0.8650949275486123
# lambda:  [0.83211059 0.92091592 0.84253962 0.85272668 0.86509493]
# a:  [0.10066514 0.02721133 0.08570688 0.07598112 0.06745254]
# b:  [0.86378827 0.83092424 0.85607419 0.86057076 0.86451345]
# c:  [0.03554659 0.14186443 0.05821893 0.06344812 0.06803401]
# delta:  [0.40040804 0.65591892 0.45569238 0.48408088 0.5       ]
# L:  [array([26.81962851, 13.7122971 ]), array([41.32339152, 20.64310996]), array([26.74293473, 20.20560502]), array([17.55410734, 35.70576635])]
# R:  [array([17.67269563, 35.48768784]), array([31.1889505 , 13.95323968]), array([41.30522852, 22.00759257]), array([22.84069616, 22.24340921])]
