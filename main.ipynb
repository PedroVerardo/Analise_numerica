# %% [markdown]
# # Spline cúbicas
# -

# %% [markdown]
# ## Generate random points

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_points = 5

arr = np.random.rand(num_points, 2)
arr = arr*50
arr
# Out:
# array([[46.75738085, 32.32565837],
#        [40.1927546 ,  6.98886971],
#        [ 0.24811674, 49.78967932],
#        [ 7.46290526,  8.63469452],
#        [18.24897119,  0.88873816]])

# %%
x = arr[:, 0]
y = arr[:, 1]

plt.scatter(x, y)

# %%
plt.scatter(x, y)
plt.plot(x, y, color='red', linewidth=1)


plt.show()

# %%
#creating a closed cubic spline
arr2 = arr.copy()
arr2[num_points - 1] = arr2[0]
arr2
# Out:
# array([[46.75738085, 32.32565837],
#        [40.1927546 ,  6.98886971],
#        [ 0.24811674, 49.78967932],
#        [ 7.46290526,  8.63469452],
#        [46.75738085, 32.32565837]])

# %%
xclosed = arr2[:, 0]
yclosed = arr2[:, 1]

plt.scatter(xclosed, yclosed)
plt.plot(xclosed, yclosed, color='red', linewidth=1)


plt.show()

# %% [markdown]
# ## Generate h vslues

# %% [markdown]
# ## Open

# %%
from spline_utils import plot_spline
import numpy as np

V = np.array([0, 0, 0, 0, 0])
plot_spline(arr, V, uniform=False)
# Out:
# open
# h:  [ 0.         26.17340592 58.5447128  41.7826034  13.27927175  0.        ]
# gamma:  [1. 1. 1. 1. 1.]
# mu:  [0.         0.20690321 0.5153285  0.75883001 0.        ]
# lambda:  [1.         0.30894697 0.66970463 0.88311178 1.        ]
# a:  [0.         0.47755429 0.13755576 0.02818993 0.        ]
# b:  [1.         0.45852359 0.56173093 0.39598708 1.        ]
# c:  [0.         0.06392212 0.30071331 0.57582299 0.        ]
# delta:  [0.         0.30894697 0.58353712 0.75883001 1.        ]
# L:  [array([44.57932363, 12.83183606]), array([ 9.51918179, 49.14882407]), array([-7.08148641, 22.89973151]), array([18.24897119,  0.88873816])]
# R:  [array([46.75738085, 32.32565837]), array([30.38087056, -6.08068598]), array([-6.36852233, 50.24704941]), array([12.08537763,  4.10100616])]

# %% [markdown]
# ## Closed

# %%
plot_spline(arr2,V, uniform=False)
# Out:
# closed
# h:  [45.88373982 26.17340592 58.5447128  41.7826034  45.88373982 45.88373982]
# gamma:  [1. 1. 1. 1. 1.]
# mu:  [0.35132532 0.20690321 0.40041235 0.31286093 0.34356953]
# lambda conta 0 :  91.76747963237077
# lambda conta 1 :  0.6666666666666666
# lambda:  [0.7780803  0.5517314  0.66970463 0.68618146 0.66666667]
# a:  [0.08060817 0.30977738 0.13755576 0.16424967 0.16666667]
# b:  [0.69567884 0.6263005  0.62878877 0.68663787 0.66154857]
# c:  [0.22371299 0.06392212 0.23365547 0.14911246 0.17178477]
# delta:  [0.63676877 0.30894697 0.58353712 0.4766094  0.5       ]
# L:  [array([44.14783254,  9.62706611]), array([ 7.87673725, 53.40187882]), array([-2.57234455, 16.14768742]), array([39.03558255, 21.13538695])]
# R:  [array([45.18031436, 23.90067824]), array([31.34603046,  1.08774814]), array([-5.19633094, 47.21169931]), array([18.48315661,  0.3842701 ])]
